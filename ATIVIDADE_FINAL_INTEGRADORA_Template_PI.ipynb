# %% [markdown]
# <a href="https://colab.research.google.com/github/WellingtonRoque/CI-CD/blob/main/ATIVIDADE_FINAL_INTEGRADORA_Template_PI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎓 ATIVIDADE FINAL INTEGRADORA
# ## Template Oficial para o Projeto Integrador (PI)
#
# ---
#
# ## 📦 Mini Projeto Modelo: TaskFlow API

# %% [markdown]
# # 🎯 OBJETIVO GERAL
#
# Desenvolver uma API Flask completa integrando:
#
# - Git e versionamento adequado
# - Pull Request
# - Testes automatizados com pytest
# - Integração Contínua (CI)
# - Branch protegida
# - Deploy automático no Render
# - Documentação profissional
#
# Esta atividade servirá como MODELO para o Projeto Integrador.

# %% [markdown]
# # 📁 Estrutura Esperada do Projeto
#
# ```
# taskflow-api/
# │
# ├── app.py
# ├── requirements.txt
# ├── tests/
# │   └── test_app.py
# ├── .github/
# │   └── workflows/
# │       └── ci.yml
# ├── README.md
# ```

# %% [markdown]
# # 📄 requirements.txt
#
# O arquivo requirements.txt deve conter EXATAMENTE:
#
# ```
# flask
# pytest
# ```
#
# ⚠ Após etapa de deploy, adicionar também:
#
# ```
# gunicorn
# ```

# %% [markdown]
# # 🔷 ETAPA 1 – Criar API Funcional
#
# A API deve possuir:
#
# - GET /
# - POST /tasks
# - GET /tasks
# - PUT /tasks/<id>

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)
tasks = []

@app.route("/")
def home():
    return jsonify({"mensagem": "TaskFlow API ativa"})

@app.route("/tasks", methods=["POST"])
def create_task():
    data = request.get_json()
    task = {
        "id": len(tasks) + 1,
        "titulo": data["titulo"],
        "concluida": False
    }
    tasks.append(task)
    return jsonify(task), 201

@app.route("/tasks", methods=["GET"])
def list_tasks():
    return jsonify(tasks)

@app.route("/tasks/<int:id>", methods=["PUT"])
def update_task(id):
    for task in tasks:
        if task["id"] == id:
            task["concluida"] = True
            return jsonify(task)
    return jsonify({"erro": "Tarefa não encontrada"}), 404

if __name__ == "__main__":
    app.run(debug=True)

# %% [markdown]
# ## ✅ Verificação 1
# - API rodando localmente
# - Rotas funcionando corretamente

# %% [markdown]
# # 🔷 ETAPA 2 – Criar Testes Automatizados
#
# Criar pasta tests e implementar no mínimo 4 testes:
#
# - Teste da rota home
# - Teste de criação de tarefa
# - Teste de listagem
# - Teste de erro 404

# %%
from app import app

def test_home():
    client = app.test_client()
    response = client.get("/")
    assert response.status_code == 200

def test_create_task():
    client = app.test_client()
    response = client.post("/tasks", json={"titulo": "Teste"})
    assert response.status_code == 201

# %% [markdown]
# ## ✅ Verificação 2
# Executar:
#
# pytest
#
# Todos os testes devem passar localmente.

# %% [markdown]
# # 🔷 ETAPA 3 – Configurar Integração Contínua (CI)
#
# Criar arquivo:
#
# .github/workflows/ci.yml

# %%
name: CI - TaskFlow

on:
  push:
    branches:
      - main
  pull_request:

jobs:
  build:
    runs-on: ubuntu-latest

    steps:
      - uses: actions/checkout@v3
      - uses: actions/setup-python@v4
        with:
          python-version: '3.11'
      - run: pip install -r requirements.txt
      - run: pytest

# %% [markdown]
# ## ✅ Verificação 3
# - Pipeline executando automaticamente
# - Pipeline verde

# %% [markdown]
# # 🔷 ETAPA 4 – Configurar Governança
#
# Configurar branch main com:
#
# - Require Pull Request
# - Require Status Checks
# - Exigir branch atualizada
#
# ## ✅ Verificação 4
# 1. Criar branch feature
# 2. Quebrar teste
# 3. Criar PR
# 4. Confirmar que merge está BLOQUEADO

# %% [markdown]
# # 🔷 ETAPA 5 – Deploy no Render
#
# Adicionar ao requirements.txt:
#
# ```
# gunicorn
# ```
#
# Ajustar app.py para produção:

# %%
import os

if __name__ == "__main__":
    port = int(os.environ.get("PORT", 5000))
    app.run(host="0.0.0.0", port=port)

# %% [markdown]
# Start Command no Render:
#
# ```
# gunicorn app:app
# ```
#
# ## ✅ Verificação 5
# - Aplicação online funcionando
# - Rotas acessíveis

# %% [markdown]
# # 🔷 ETAPA 6 – Simulação Final Completa
#
# Demonstrar:
#
# 1. Criar feature branch
# 2. Alterar código
# 3. Criar PR
# 4. CI rodar
# 5. Merge
# 6. Deploy automático
# 7. Alteração visível online

# %% [markdown]
# # 📦 ENTREGÁVEIS OBRIGATÓRIOS
#
# 1. Link do repositório GitHub
# 2. Link da aplicação no Render
# 3. Print da branch protegida
# 4. Print do merge bloqueado
# 5. Print da pipeline verde
# 6. README profissional

# %% [markdown]
# # 📊 CRITÉRIOS DE AVALIAÇÃO (10 pontos)
#
# | Critério | Pontos |
# |----------|--------|
# | API funcional | 2 |
# | Testes automatizados | 2 |
# | CI configurada | 2 |
# | Governança ativa | 1 |
# | Deploy funcionando | 2 |
# | README estruturado | 1 |
